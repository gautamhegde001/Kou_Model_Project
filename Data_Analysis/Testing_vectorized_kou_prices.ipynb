# %%
import numpy as np
import pandas as pd
from pathlib import Path

input_dir = Path.cwd().parent / 'datafiles'
input_filename = "kou_prices_fft_vectorized.pkl"
input_path = input_dir/input_filename

df = pd.read_pickle(input_path)

df.head()
# Out:
#      S_0    K    T          C
# 0  100.0   90  1.0  17.127890
# 1  100.0   85  1.0  20.915759
# 2  100.0   83  1.0  22.526011
# 3  100.0  105  1.0   8.105601
# 4  100.0  110  1.0   5.974879

# %%
import numpy as np
